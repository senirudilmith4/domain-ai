# %%
# !pip install ctgan
# Out:
# Requirement already satisfied: ctgan in /usr/local/lib/python3.12/dist-packages (0.11.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from ctgan) (1.26.4)
# Requirement already satisfied: pandas>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from ctgan) (2.2.2)
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from ctgan) (2.9.0+cpu)
# Requirement already satisfied: tqdm<5,>=4.29 in /usr/local/lib/python3.12/dist-packages (from ctgan) (4.66.5)
# Requirement already satisfied: rdt>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from ctgan) (1.18.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.1->ctgan) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.1->ctgan) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.1->ctgan) (2025.3)
# Requirement already satisfied: scipy>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from rdt>=1.14.0->ctgan) (1.12.0)
# Requirement already satisfied: scikit-learn>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from rdt>=1.14.0->ctgan) (1.5.1)
# Requirement already satisfied: Faker!=37.11.0,>=17 in /usr/local/lib/python3.12/dist-packages (from rdt>=1.14.0->ctgan) (39.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan) (2025.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.1.1->ctgan) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.1->rdt>=1.14.0->ctgan) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.1->rdt>=1.14.0->ctgan) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.3.0->ctgan) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.3.0->ctgan) (3.0.3)

# %%
import pandas as pd
import numpy as np
from ctgan import CTGAN

# %%
# !pip install table_evaluator
# Out:
# Requirement already satisfied: table_evaluator in /usr/local/lib/python3.12/dist-packages (1.9.0)
# Requirement already satisfied: pyarrow==17.0.0 in /usr/local/lib/python3.12/dist-packages (from table_evaluator) (17.0.0)
# Requirement already satisfied: scikit-learn==1.5.1 in /usr/local/lib/python3.12/dist-packages (from table_evaluator) (1.5.1)
# Requirement already satisfied: tqdm==4.66.5 in /usr/local/lib/python3.12/dist-packages (from table_evaluator) (4.66.5)
# Requirement already satisfied: matplotlib==3.9.2 in /usr/local/lib/python3.12/dist-packages (from table_evaluator) (3.9.2)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.12/dist-packages (from table_evaluator) (1.26.4)
# Requirement already satisfied: seaborn==0.13.2 in /usr/local/lib/python3.12/dist-packages (from table_evaluator) (0.13.2)
# Requirement already satisfied: pandas==2.2.2 in /usr/local/lib/python3.12/dist-packages (from table_evaluator) (2.2.2)
# Requirement already satisfied: scipy==1.12.0 in /usr/local/lib/python3.12/dist-packages (from table_evaluator) (1.12.0)
# Requirement already satisfied: pre-commit==3.8.0 in /usr/local/lib/python3.12/dist-packages (from table_evaluator) (3.8.0)
# Requirement already satisfied: ipython==8.28.0 in /usr/local/lib/python3.12/dist-packages (from table_evaluator) (8.28.0)
# Requirement already satisfied: pytest==8.3.2 in /usr/local/lib/python3.12/dist-packages (from table_evaluator) (8.3.2)
# Requirement already satisfied: sphinx==7.3.1 in /usr/local/lib/python3.12/dist-packages (from table_evaluator) (7.3.1)
# Requirement already satisfied: pytest-cov==4.0.0 in /usr/local/lib/python3.12/dist-packages (from table_evaluator) (4.0.0)
# Requirement already satisfied: pytest-mock==3.14.0 in /usr/local/lib/python3.12/dist-packages (from table_evaluator) (3.14.0)
# Requirement already satisfied: m2r2==0.3.3.post2 in /usr/local/lib/python3.12/dist-packages (from table_evaluator) (0.3.3.post2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from table_evaluator) (75.2.0)
# Requirement already satisfied: sphinx-rtd-theme==2.0.0 in /usr/local/lib/python3.12/dist-packages (from table_evaluator) (2.0.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython==8.28.0->table_evaluator) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython==8.28.0->table_evaluator) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython==8.28.0->table_evaluator) (0.2.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.12/dist-packages (from ipython==8.28.0->table_evaluator) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from ipython==8.28.0->table_evaluator) (2.19.2)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.12/dist-packages (from ipython==8.28.0->table_evaluator) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /usr/local/lib/python3.12/dist-packages (from ipython==8.28.0->table_evaluator) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython==8.28.0->table_evaluator) (4.9.0)
# Requirement already satisfied: mistune==0.8.4 in /usr/local/lib/python3.12/dist-packages (from m2r2==0.3.3.post2->table_evaluator) (0.8.4)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.12/dist-packages (from m2r2==0.3.3.post2->table_evaluator) (0.20.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2->table_evaluator) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2->table_evaluator) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2->table_evaluator) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2->table_evaluator) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2->table_evaluator) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2->table_evaluator) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2->table_evaluator) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2->table_evaluator) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2->table_evaluator) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2->table_evaluator) (2025.3)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit==3.8.0->table_evaluator) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit==3.8.0->table_evaluator) (2.6.15)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from pre-commit==3.8.0->table_evaluator) (1.10.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from pre-commit==3.8.0->table_evaluator) (6.0.3)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit==3.8.0->table_evaluator) (20.35.4)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.12/dist-packages (from pytest==8.3.2->table_evaluator) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest==8.3.2->table_evaluator) (1.6.0)
# Requirement already satisfied: coverage>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from coverage[toml]>=5.2.1->pytest-cov==4.0.0->table_evaluator) (7.13.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.5.1->table_evaluator) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.5.1->table_evaluator) (3.6.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.12/dist-packages (from sphinx==7.3.1->table_evaluator) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.12/dist-packages (from sphinx==7.3.1->table_evaluator) (2.0.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.12/dist-packages (from sphinx==7.3.1->table_evaluator) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from sphinx==7.3.1->table_evaluator) (2.1.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.12/dist-packages (from sphinx==7.3.1->table_evaluator) (2.0.0)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.12/dist-packages (from sphinx==7.3.1->table_evaluator) (2.0.0)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.12/dist-packages (from sphinx==7.3.1->table_evaluator) (3.1.6)
# Requirement already satisfied: snowballstemmer>=2.0 in /usr/local/lib/python3.12/dist-packages (from sphinx==7.3.1->table_evaluator) (3.0.1)
# Requirement already satisfied: babel>=2.9 in /usr/local/lib/python3.12/dist-packages (from sphinx==7.3.1->table_evaluator) (2.17.0)
# Requirement already satisfied: alabaster~=0.7.14 in /usr/local/lib/python3.12/dist-packages (from sphinx==7.3.1->table_evaluator) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.12/dist-packages (from sphinx==7.3.1->table_evaluator) (1.4.1)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.12/dist-packages (from sphinx==7.3.1->table_evaluator) (2.32.4)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /usr/local/lib/python3.12/dist-packages (from sphinx-rtd-theme==2.0.0->table_evaluator) (4.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython==8.28.0->table_evaluator) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2>=3.0->sphinx==7.3.1->table_evaluator) (3.0.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython==8.28.0->table_evaluator) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython==8.28.0->table_evaluator) (0.2.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib==3.9.2->table_evaluator) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25.0->sphinx==7.3.1->table_evaluator) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25.0->sphinx==7.3.1->table_evaluator) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25.0->sphinx==7.3.1->table_evaluator) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25.0->sphinx==7.3.1->table_evaluator) (2025.11.12)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit==3.8.0->table_evaluator) (0.4.0)
# Requirement already satisfied: filelock<4,>=3.12.2 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit==3.8.0->table_evaluator) (3.20.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit==3.8.0->table_evaluator) (4.5.1)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from stack-data->ipython==8.28.0->table_evaluator) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from stack-data->ipython==8.28.0->table_evaluator) (3.0.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.12/dist-packages (from stack-data->ipython==8.28.0->table_evaluator) (0.2.3)

# %%
df = pd.read_csv("/content/sample_data/dataset.csv")

# %%
df
# Out:
#        Stage hours_per_week   academic_stress  \
# 0    Stage 1       3 - 5 hrs                4
# 1    Stage 2       3 - 5 hrs                4
# 2    Stage 1  Less than 3hrs                2
# 3    Stage 1       3 - 5 hrs                5
# 4    Stage 2  Less than 3hrs                4
# ..       ...             ...              ...
# 153  Stage 1  Less than 3hrs                3
# 154  Stage 3      5 - 10 hrs                3
# 155  Stage 2       3 - 5 hrs                4
# 156  Stage 3      5 - 10 hrs                3
# 157  Stage 4      5 - 10 hrs                3
#
#                         choosing_new_courses_decision   \
# 0    Personal interest in the subject;Career or job...
# 1                              Career or job relevance
# 2    Personal interest in the subject;Recommendatio...
# 3                              Career or job relevance
# 4                              Career or job relevance
# ..                                                 ...
# 153                            Career or job relevance
# 154                            Career or job relevance
# 155                            Career or job relevance
# 156                   Personal interest in the subject
# 157                            Career or job relevance
#
#                                     Mng_academic_tasks  \
# 0    To-do list or planner apps;I usually remember ...
# 1                              Notes on phone or paper
# 2                     I usually remember them mentally
# 3                     I usually remember them mentally
# 4                     I usually remember them mentally
# ..                                                 ...
# 153                   I usually remember them mentally
# 154                         To-do list or planner apps
# 155                   I usually remember them mentally
# 156                         To-do list or planner apps
# 157                         To-do list or planner apps
#
#     struggle_with_managing   \
# 0                     Often
# 1                 Sometimes
# 2                    Rarely
# 3                    Always
# 4                 Sometimes
# ..                      ...
# 153               Sometimes
# 154               Sometimes
# 155                  Always
# 156                  Rarely
# 157                  Rarely
#
#                           challenges_handling_workload  \
# 0    Forgetting deadlines or exam dates;Not knowing...
# 1               Balancing multiple courses or projects
# 2    Not knowing how to prioritize task;Starting ta...
# 3               Balancing multiple courses or projects
# 4                              Starting tasks too late
# ..                                                 ...
# 153                            Starting tasks too late
# 154                 Not knowing how to prioritize task
# 155                            Starting tasks too late
# 156             Balancing multiple courses or projects
# 157             Balancing multiple courses or projects
#
#      start_assignments_closer_deadline  Skill_Programming  Skill_Math  ...  \
# 0                               Always                  3           2  ...
# 1                            Sometimes                  4           4  ...
# 2                               Always                  3           3  ...
# 3                               Always                  3           2  ...
# 4                            Sometimes                  2           3  ...
# ..                                 ...                ...         ...  ...
# 153                          Sometimes                  4           3  ...
# 154                          Sometimes                  4           3  ...
# 155                             Always                  3           2  ...
# 156                          Sometimes                  4           5  ...
# 157                          Sometimes                  4           4  ...
#
#      Grade_CM3606  Grade_CM3604  Grade_CM3602 Grade_CM3603 Grade_CM4605  \
# 0               -             -             -            -            -
# 1               -             -             -            -            -
# 2               -             -             -            -            -
# 3               -             -             -            -            -
# 4               -             -             -            -            -
# ..            ...           ...           ...          ...          ...
# 153             -             -             -            -            -
# 154             D             C             D            -            -
# 155             -             -             -            -            -
# 156             C             C             C            -            -
# 157             C             C             -            B            C
#
#     Grade_CM4604 Grade_CM4601 Grade_CM4606 Grade_CM4603 Predicted_Success_DL
# 0              -            -            -            -                  NaN
# 1              -            -            -            -                    -
# 2              -            -            -            -                  NaN
# 3              -            -            -            -                  NaN
# 4              -            -            -            -                    -
# ..           ...          ...          ...          ...                  ...
# 153            -            -            -            -                  NaN
# 154            -            -            -            -                   72
# 155            -            -            -            -                    -
# 156            -            -            -            -                   87
# 157            C            C            -            B                   75
#
# [158 rows x 37 columns]

# %%
df = df.replace('-', np.nan)

# %%
df
# Out:
#        Stage hours_per_week   academic_stress  \
# 0    Stage 1       3 - 5 hrs                4
# 1    Stage 2       3 - 5 hrs                4
# 2    Stage 1  Less than 3hrs                2
# 3    Stage 1       3 - 5 hrs                5
# 4    Stage 2  Less than 3hrs                4
# ..       ...             ...              ...
# 153  Stage 1  Less than 3hrs                3
# 154  Stage 3      5 - 10 hrs                3
# 155  Stage 2       3 - 5 hrs                4
# 156  Stage 3      5 - 10 hrs                3
# 157  Stage 4      5 - 10 hrs                3
#
#                         choosing_new_courses_decision   \
# 0    Personal interest in the subject;Career or job...
# 1                              Career or job relevance
# 2    Personal interest in the subject;Recommendatio...
# 3                              Career or job relevance
# 4                              Career or job relevance
# ..                                                 ...
# 153                            Career or job relevance
# 154                            Career or job relevance
# 155                            Career or job relevance
# 156                   Personal interest in the subject
# 157                            Career or job relevance
#
#                                     Mng_academic_tasks  \
# 0    To-do list or planner apps;I usually remember ...
# 1                              Notes on phone or paper
# 2                     I usually remember them mentally
# 3                     I usually remember them mentally
# 4                     I usually remember them mentally
# ..                                                 ...
# 153                   I usually remember them mentally
# 154                         To-do list or planner apps
# 155                   I usually remember them mentally
# 156                         To-do list or planner apps
# 157                         To-do list or planner apps
#
#     struggle_with_managing   \
# 0                     Often
# 1                 Sometimes
# 2                    Rarely
# 3                    Always
# 4                 Sometimes
# ..                      ...
# 153               Sometimes
# 154               Sometimes
# 155                  Always
# 156                  Rarely
# 157                  Rarely
#
#                           challenges_handling_workload  \
# 0    Forgetting deadlines or exam dates;Not knowing...
# 1               Balancing multiple courses or projects
# 2    Not knowing how to prioritize task;Starting ta...
# 3               Balancing multiple courses or projects
# 4                              Starting tasks too late
# ..                                                 ...
# 153                            Starting tasks too late
# 154                 Not knowing how to prioritize task
# 155                            Starting tasks too late
# 156             Balancing multiple courses or projects
# 157             Balancing multiple courses or projects
#
#      start_assignments_closer_deadline  Skill_Programming  Skill_Math  ...  \
# 0                               Always                  3           2  ...
# 1                            Sometimes                  4           4  ...
# 2                               Always                  3           3  ...
# 3                               Always                  3           2  ...
# 4                            Sometimes                  2           3  ...
# ..                                 ...                ...         ...  ...
# 153                          Sometimes                  4           3  ...
# 154                          Sometimes                  4           3  ...
# 155                             Always                  3           2  ...
# 156                          Sometimes                  4           5  ...
# 157                          Sometimes                  4           4  ...
#
#      Grade_CM3606  Grade_CM3604  Grade_CM3602 Grade_CM3603 Grade_CM4605  \
# 0             NaN           NaN           NaN          NaN          NaN
# 1             NaN           NaN           NaN          NaN          NaN
# 2             NaN           NaN           NaN          NaN          NaN
# 3             NaN           NaN           NaN          NaN          NaN
# 4             NaN           NaN           NaN          NaN          NaN
# ..            ...           ...           ...          ...          ...
# 153           NaN           NaN           NaN          NaN          NaN
# 154             D             C             D          NaN          NaN
# 155           NaN           NaN           NaN          NaN          NaN
# 156             C             C             C          NaN          NaN
# 157             C             C           NaN            B            C
#
#     Grade_CM4604 Grade_CM4601 Grade_CM4606 Grade_CM4603 Predicted_Success_DL
# 0            NaN          NaN          NaN          NaN                  NaN
# 1            NaN          NaN          NaN          NaN                  NaN
# 2            NaN          NaN          NaN          NaN                  NaN
# 3            NaN          NaN          NaN          NaN                  NaN
# 4            NaN          NaN          NaN          NaN                  NaN
# ..           ...          ...          ...          ...                  ...
# 153          NaN          NaN          NaN          NaN                  NaN
# 154          NaN          NaN          NaN          NaN                   72
# 155          NaN          NaN          NaN          NaN                  NaN
# 156          NaN          NaN          NaN          NaN                   87
# 157            C            C          NaN            B                   75
#
# [158 rows x 37 columns]

# %%
grade_cols = [col for col in df.columns if 'Grade_' in col]
rating_cols = [col for col in df.columns if 'Skill_' in col or col == 'academic_stress']
continuous_col = 'Predicted_Success_DL'

# %%
# **FIX:** Explicitly convert the continuous column to numeric.
# This ensures median() can operate correctly on numerical data.
df[continuous_col] = pd.to_numeric(df[continuous_col], errors='coerce')

# %%
for col in grade_cols + rating_cols:
    # Use .astype(str) and replace pandas NaT/None with np.nan for consistent filling
    df[col] = df[col].astype(str).replace('<NA>', np.nan)

# %%
def impute_not_taken(row):
    try:
        stage = int(row['Stage'].split(' ')[-1])
    except:
        return row

    # Correct prefixes to match actual dataset columns
    if stage == 1:
        not_expected_prefixes = ['Grade_CM26', 'Grade_CM36', 'Grade_CM46']
    elif stage == 2:
        not_expected_prefixes = ['Grade_CM36', 'Grade_CM46']
    elif stage == 3:
        not_expected_prefixes = ['Grade_CM46']
    else:
        not_expected_prefixes = []

    for col in grade_cols:
        if any(col.startswith(prefix) for prefix in not_expected_prefixes):
            if pd.isna(row[col]):
                row[col] = 'NOT_TAKEN'

    return row

# %%
df = df.apply(impute_not_taken, axis=1)

# %%
categorical_cols_for_mode = [col for col in df.columns if col != continuous_col]

# %%
for col in categorical_cols_for_mode:
    # Calculate the mode only on existing, non-NaN, non-NOT_TAKEN values
    # This prevents 'NOT_TAKEN' from skewing the mode of actual grades.
    mode_val_series = df[col].replace('NOT_TAKEN', np.nan).mode()

    if not mode_val_series.empty:
        # Impute remaining NaNs with the calculated mode
        df[col].fillna(mode_val_series.iloc[0], inplace=True)
    else:
        # Fallback for columns with no valid mode (shouldn't happen here)
        df[col].fillna('Unknown', inplace=True)
# Out:
# /tmp/ipython-input-2593449422.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(mode_val_series.iloc[0], inplace=True)

# %%
# Impute the continuous column with the median
median_val = df[continuous_col].median()
df[continuous_col].fillna(median_val, inplace=True)
# Out:
# /tmp/ipython-input-2537632818.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[continuous_col].fillna(median_val, inplace=True)

# %%
final_categorical_cols = [col for col in df.columns if col != continuous_col]

# %%
print("--- Preprocessing Complete ---")
print("Data head (first 5 rows):")
print(df.head())
print("\nFinal Categorical Columns for CTGAN (37 columns):")
print(final_categorical_cols)
# Out:
# --- Preprocessing Complete ---
# Data head (first 5 rows):
#      Stage hours_per_week  academic_stress  \
# 0  Stage 1       3 - 5 hrs               4
# 1  Stage 2       3 - 5 hrs               4
# 2  Stage 1  Less than 3hrs               2
# 3  Stage 1       3 - 5 hrs               5
# 4  Stage 2  Less than 3hrs               4
#
#                       choosing_new_courses_decision   \
# 0  Personal interest in the subject;Career or job...
# 1                            Career or job relevance
# 2  Personal interest in the subject;Recommendatio...
# 3                            Career or job relevance
# 4                            Career or job relevance
#
#                                   Mng_academic_tasks struggle_with_managing   \
# 0  To-do list or planner apps;I usually remember ...                   Often
# 1                            Notes on phone or paper               Sometimes
# 2                   I usually remember them mentally                  Rarely
# 3                   I usually remember them mentally                  Always
# 4                   I usually remember them mentally               Sometimes
#
#                         challenges_handling_workload  \
# 0  Forgetting deadlines or exam dates;Not knowing...
# 1             Balancing multiple courses or projects
# 2  Not knowing how to prioritize task;Starting ta...
# 3             Balancing multiple courses or projects
# 4                            Starting tasks too late
#
#    start_assignments_closer_deadline Skill_Programming Skill_Math  ...  \
# 0                             Always                 3          2  ...
# 1                          Sometimes                 4          4  ...
# 2                             Always                 3          3  ...
# 3                             Always                 3          2  ...
# 4                          Sometimes                 2          3  ...
#
#   Grade_CM3606 Grade_CM3604 Grade_CM3602 Grade_CM3603 Grade_CM4605  \
# 0          nan          nan          nan          nan          nan
# 1          nan          nan          nan          nan          nan
# 2          nan          nan          nan          nan          nan
# 3          nan          nan          nan          nan          nan
# 4          nan          nan          nan          nan          nan
#
#   Grade_CM4604 Grade_CM4601 Grade_CM4606 Grade_CM4603 Predicted_Success_DL
# 0          nan          nan          nan          nan                 75.0
# 1          nan          nan          nan          nan                 75.0
# 2          nan          nan          nan          nan                 75.0
# 3          nan          nan          nan          nan                 75.0
# 4          nan          nan          nan          nan                 75.0
#
# [5 rows x 37 columns]
#
# Final Categorical Columns for CTGAN (37 columns):
# ['Stage', 'hours_per_week ', 'academic_stress', 'choosing_new_courses_decision ', 'Mng_academic_tasks', 'struggle_with_managing ', 'challenges_handling_workload', ' start_assignments_closer_deadline', 'Skill_Programming', 'Skill_Math', 'Skill_DS_Algo', 'Skill_Technical_Comm', 'Skill_Web_Development', 'Grade_CM1601', 'Grade_CM1602', 'Grade_CM1603', 'Grade_CM1604', 'Grade_CM1605', 'Grade_CM1606', 'Grade_CM1607', 'Grade_CM2601', 'Grade_CM2602', 'Grade_CM2603', 'Grade_CM2604', 'Grade_CM2605', 'Grade_CM2606', 'Grade_CM2607', 'Grade_CM3606', 'Grade_CM3604', 'Grade_CM3602', 'Grade_CM3603', 'Grade_CM4605', 'Grade_CM4604', 'Grade_CM4601', 'Grade_CM4606', 'Grade_CM4603']

# %%
df.to_csv('corrected_preprocessed_data_for_ctgan.csv', index=False)

# %% [markdown]
# # *CTGAN Training*

# %%
data = pd.read_csv('corrected_preprocessed_data_for_ctgan.csv')
final_categorical_cols = [
    'Stage', 'hours_per_week', 'academic_stress', 'choosing_new_courses_decision',
    'Mng_academic_tasks', 'struggle_with_managing', 'challenges_handling_workload',
    'start_assignments_closer_deadline', 'Skill_Programming', 'Skill_Math',
    'Skill_DS_Algo', 'Skill_Technical_Comm', 'Skill_Web_Development',
    'Grade_CM1601', 'Grade_CM1602', 'Grade_CM1603', 'Grade_CM1604',
    'Grade_CM1605', 'Grade_CM1606', 'Grade_CM1607', 'Grade_CM2601',
    'Grade_CM2602', 'Grade_CM2603', 'Grade_CM2604', 'Grade_CM2605',
    'Grade_CM2606', 'Grade_CM2607', 'Grade_CM3606', 'Grade_CM3604',
    'Grade_CM3602', 'Grade_CM3603', 'Grade_CM4605', 'Grade_CM4604',
    'Grade_CM4601', 'Grade_CM4606', 'Grade_CM4603'
]

# %%
continuous_col = 'Predicted_Success_DL'
final_categorical_cols = [col for col in data.columns if col != continuous_col]

# %%
ctgan = CTGAN(epochs=500, batch_size=500)
print("--- Starting CTGAN Training ---")
ctgan.fit(data, final_categorical_cols)
print("--- CTGAN Training Complete ---")
# Out:
# --- Starting CTGAN Training ---
# --- CTGAN Training Complete ---

# %%
# Generate new synthetic samples (e.g., 1000 new rows)
synthetic_data = ctgan.sample(10000)

# %%
print("\n--- Synthetic Data Generated ---")
print(synthetic_data.head())
# Out:
# --- Synthetic Data Generated ---
#      Stage hours_per_week   academic_stress    choosing_new_courses_decision   \
# 0  Stage 4  Less than 3hrs                3  Personal interest in the subject
# 1  Stage 2       3 - 5 hrs                4           Career or job relevance
# 2  Stage 1  Less than 3hrs                3           Career or job relevance
# 3  Stage 1  Less than 3hrs                4           Career or job relevance
# 4  Stage 1      5 - 10 hrs                3           Career or job relevance
#
#                  Mng_academic_tasks struggle_with_managing   \
# 0        To-do list or planner apps                  Rarely
# 1           Notes on phone or paper               Sometimes
# 2           Notes on phone or paper                  Always
# 3  I usually remember them mentally               Sometimes
# 4           Notes on phone or paper               Sometimes
#
#              challenges_handling_workload  start_assignments_closer_deadline  \
# 0  Balancing multiple courses or projects                          Sometimes
# 1                 Starting tasks too late                          Sometimes
# 2                 Starting tasks too late                          Sometimes
# 3                 Starting tasks too late                             Always
# 4                 Starting tasks too late                          Sometimes
#
#    Skill_Programming  Skill_Math  ...  Grade_CM3606  Grade_CM3604  \
# 0                  4           3  ...             C             C
# 1                  3           3  ...           NaN           NaN
# 2                  3           3  ...           NaN           NaN
# 3                  4           3  ...           NaN           NaN
# 4                  3           3  ...           NaN           NaN
#
#    Grade_CM3602 Grade_CM3603 Grade_CM4605 Grade_CM4604 Grade_CM4601  \
# 0             C            B          NaN            C            C
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN            C          NaN          NaN          NaN
#
#   Grade_CM4606 Grade_CM4603 Predicted_Success_DL
# 0          NaN          NaN            73.980124
# 1          NaN          NaN            73.358637
# 2            B          NaN            83.667005
# 3          NaN          NaN            75.432153
# 4          NaN            C            74.162637
#
# [5 rows x 37 columns]

# %%
def enforce_grade_consistency(row):
    """Resets grades for future modules based on the student's Stage."""
    try:
        stage = int(row['Stage'].split(' ')[-1])
    except:
        return row

    # Correct prefixes to match real column names
    not_expected_prefixes = []
    if stage == 1:
        not_expected_prefixes.extend(['Grade_CM26', 'Grade_CM36', 'Grade_CM46'])
    elif stage == 2:
        not_expected_prefixes.extend(['Grade_CM36', 'Grade_CM46'])
    elif stage == 3:
        not_expected_prefixes.extend(['Grade_CM46'])

    grade_cols = [c for c in row.index if c.startswith('Grade_CM')]

    for col in grade_cols:
        if any(col.startswith(prefix) for prefix in not_expected_prefixes):
            row[col] = 'NOT_TAKEN'

    return row


# Apply correction
synthetic_data_corrected = synthetic_data.apply(enforce_grade_consistency, axis=1)

# %%
print("\n--- Synthetic Data Correction Applied ---")
print("First 5 corrected rows:")
print(synthetic_data_corrected.head())
# Out:
# --- Synthetic Data Correction Applied ---
# First 5 corrected rows:
#      Stage hours_per_week   academic_stress    choosing_new_courses_decision   \
# 0  Stage 4  Less than 3hrs                3  Personal interest in the subject
# 1  Stage 2       3 - 5 hrs                4           Career or job relevance
# 2  Stage 1  Less than 3hrs                3           Career or job relevance
# 3  Stage 1  Less than 3hrs                4           Career or job relevance
# 4  Stage 1      5 - 10 hrs                3           Career or job relevance
#
#                  Mng_academic_tasks struggle_with_managing   \
# 0        To-do list or planner apps                  Rarely
# 1           Notes on phone or paper               Sometimes
# 2           Notes on phone or paper                  Always
# 3  I usually remember them mentally               Sometimes
# 4           Notes on phone or paper               Sometimes
#
#              challenges_handling_workload  start_assignments_closer_deadline  \
# 0  Balancing multiple courses or projects                          Sometimes
# 1                 Starting tasks too late                          Sometimes
# 2                 Starting tasks too late                          Sometimes
# 3                 Starting tasks too late                             Always
# 4                 Starting tasks too late                          Sometimes
#
#    Skill_Programming  Skill_Math  ...  Grade_CM3606  Grade_CM3604  \
# 0                  4           3  ...             C             C
# 1                  3           3  ...     NOT_TAKEN     NOT_TAKEN
# 2                  3           3  ...     NOT_TAKEN     NOT_TAKEN
# 3                  4           3  ...     NOT_TAKEN     NOT_TAKEN
# 4                  3           3  ...     NOT_TAKEN     NOT_TAKEN
#
#    Grade_CM3602 Grade_CM3603 Grade_CM4605 Grade_CM4604 Grade_CM4601  \
# 0             C            B          NaN            C            C
# 1     NOT_TAKEN    NOT_TAKEN    NOT_TAKEN    NOT_TAKEN    NOT_TAKEN
# 2     NOT_TAKEN    NOT_TAKEN    NOT_TAKEN    NOT_TAKEN    NOT_TAKEN
# 3     NOT_TAKEN    NOT_TAKEN    NOT_TAKEN    NOT_TAKEN    NOT_TAKEN
# 4     NOT_TAKEN    NOT_TAKEN    NOT_TAKEN    NOT_TAKEN    NOT_TAKEN
#
#   Grade_CM4606 Grade_CM4603 Predicted_Success_DL
# 0          NaN          NaN            73.980124
# 1    NOT_TAKEN    NOT_TAKEN            73.358637
# 2    NOT_TAKEN    NOT_TAKEN            83.667005
# 3    NOT_TAKEN    NOT_TAKEN            75.432153
# 4    NOT_TAKEN    NOT_TAKEN            74.162637
#
# [5 rows x 37 columns]

# %%
from table_evaluator import TableEvaluator

print(data.shape, synthetic_data_corrected.shape)
table_evaluator =  TableEvaluator(data, synthetic_data_corrected , cat_cols= final_categorical_cols)

table_evaluator.visual_evaluation()
# Out:
# (158, 37) (10000, 37)

# %%
synthetic_data_corrected.to_csv('fin_synthetic_samples.csv', index=False)

# %%
synthetic_data_corrected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 37 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Stage                               10000 non-null  object
#  1   hours_per_week                      10000 non-null  object
#  2   academic_stress                     10000 non-null  int64
#  3   choosing_new_courses_decision       10000 non-null  object
#  4   Mng_academic_tasks                  10000 non-null  object
#  5   struggle_with_managing              10000 non-null  object
#  6   challenges_handling_workload        10000 non-null  object
#  7    start_assignments_closer_deadline  10000 non-null  object
#  8   Skill_Programming                   10000 non-null  int64
#  9   Skill_Math                          10000 non-null  int64
#  10  Skill_DS_Algo                       10000 non-null  int64
#  11  Skill_Technical_Comm                10000 non-null  int64
#  12  Skill_Web_Development               10000 non-null  int64
#  13  Grade_CM1601                        10000 non-null  object
#  14  Grade_CM1602                        10000 non-null  object
#  15  Grade_CM1603                        10000 non-null  object
#  16  Grade_CM1604                        10000 non-null  object
#  17  Grade_CM1605                        10000 non-null  object
#  18  Grade_CM1606                        10000 non-null  object
#  19  Grade_CM1607                        10000 non-null  object
#  20  Grade_CM2601                        8573 non-null   object
#  21  Grade_CM2602                        8755 non-null   object
#  22  Grade_CM2603                        8517 non-null   object
#  23  Grade_CM2604                        8642 non-null   object
#  24  Grade_CM2605                        8526 non-null   object
#  25  Grade_CM2606                        8536 non-null   object
#  26  Grade_CM2607                        8727 non-null   object
#  27  Grade_CM3606                        8662 non-null   object
#  28  Grade_CM3604                        8664 non-null   object
#  29  Grade_CM3602                        7812 non-null   object
#  30  Grade_CM3603                        5936 non-null   object
#  31  Grade_CM4605                        8779 non-null   object
#  32  Grade_CM4604                        8868 non-null   object
#  33  Grade_CM4601                        8889 non-null   object
#  34  Grade_CM4606                        8483 non-null   object
#  35  Grade_CM4603                        8465 non-null   object
#  36  Predicted_Success_DL                10000 non-null  float64
# dtypes: float64(1), int64(6), object(30)
# memory usage: 2.8+ MB
